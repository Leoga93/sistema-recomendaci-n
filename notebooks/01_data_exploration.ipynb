# %% [markdown]
# # Análisis exploratorio de datos

# %%
# Cargando librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Carga y revisión de los datos

# %% [markdown]
# ### Tamaño del conjunto de datos

# %%
import os 

url = "C:/Users/USUARIO/Desktop/Proyectos/Sistema_recomendacion/data/raw/data_raw.csv"

if os.path.exists(url): 
    data = pd.read_csv(url, sep=',', encoding='latin1')
    print("Carga exitosa:", data.shape)
else:
    print("Archivo no encontrado. verifica la ruta.")
# Out:
# Carga exitosa: (51290, 24)

# %%
data.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# 0   TEC-AC-10003033  Technology  Accessories
# 1   FUR-CH-10003950   Furniture       Chairs
# 2   TEC-PH-10004664  Technology       Phones
# 3   TEC-PH-10004583  Technology       Phones
# 4  TEC-SHA-10000501  Technology      Copiers
#
#                                         Product Name     Sales Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1          Novimex Executive Leather Armchair, Black  3709.395        9
# 2                  Nokia Smart Phone, with Caller ID  5175.171        9
# 3                     Motorola Smart Phone, Cordless  2892.510        5
# 4                     Sharp Wireless Fax, High-Speed  2832.960        8
#
#   Discount    Profit  Shipping Cost  Order Priority
# 0      0.0  762.1845         933.57        Critical
# 1      0.1 -288.7650         923.63        Critical
# 2      0.1  919.9710         915.49          Medium
# 3      0.1  -96.5400         910.16          Medium
# 4      0.0  311.5200         903.04        Critical
#
# [5 rows x 24 columns]

# %%
data.tail()
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 51285   29002   IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398  US-2014-102288  20-06-2014  24-06-2014  Standard Class
# 51287   40470  US-2013-155768  02-12-2013  02-12-2013        Same Day
# 51288    9596  MX-2012-140767  18-02-2012  22-02-2012  Standard Class
# 51289    6147  MX-2012-134460  22-05-2012  26-05-2012    Second Class
#
#       Customer ID     Customer Name      Segment      City       State  ...  \
# 51285    KE-16420   Katrina Edelman    Corporate      Kure   Hiroshima  ...
# 51286    ZC-21910  Zuschuss Carroll     Consumer   Houston       Texas  ...
# 51287    LB-16795    Laurel Beltran  Home Office    Oxnard  California  ...
# 51288    RB-19795        Ross Baird  Home Office  Valinhos   São Paulo  ...
# 51289    MC-18100     Mick Crebagga     Consumer  Tipitapa     Managua  ...
#
#             Product ID         Category Sub-Category  \
# 51285  OFF-FA-10000746  Office Supplies    Fasteners
# 51286  OFF-AP-10002906  Office Supplies   Appliances
# 51287  OFF-EN-10001219  Office Supplies    Envelopes
# 51288  OFF-BI-10000806  Office Supplies      Binders
# 51289  OFF-PA-10004155  Office Supplies        Paper
#
#                                             Product Name   Sales Quantity  \
# 51285                      Advantus Thumb Tacks, 12 Pack  65.100        5
# 51286  Hoover Replacement Belt for Commercial Guardsm...   0.444        1
# 51287       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes  22.920        3
# 51288                            Acco Index Tab, Economy  13.440        2
# 51289            Eaton Computer Printout Paper, 8.5 x 11  61.380        3
#
#       Discount   Profit  Shipping Cost  Order Priority
# 51285      0.0   4.5000           0.01          Medium
# 51286      0.8  -1.1100           0.01          Medium
# 51287      0.0  11.2308           0.01            High
# 51288      0.0   2.4000           0.00          Medium
# 51289      0.0   1.8000           0.00            High
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Nombres de las columnas

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# ### Tipo de datos de las columnas

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
#  17  Product Name    51290 non-null  object
#  18  Sales           51290 non-null  float64
#  19  Quantity        51290 non-null  int64
#  20  Discount        51290 non-null  float64
#  21  Profit          51290 non-null  float64
#  22  Shipping Cost   51290 non-null  float64
#  23  Order Priority  51290 non-null  object
# dtypes: float64(5), int64(2), object(17)
# memory usage: 9.4+ MB
# None

# %% [markdown]
# * El conjunto de datos tiene un tamaño de 24 columnas y 51290 filas.
#
# Las columnas del conjunto de datos son:
#
# 1. Row ID: Identificador para cada fila.
# 2. Order ID: Identificador único para cada orden de venta.
# 3. Order Date: Fecha de la orden de venta.
# 4. Ship Date: Fecha de envío del pedido.
# 5. Ship Mode: Modo de envío del pedido.
# 6. Customer ID: Identificador único para cada cliente.
# 7. Customer Name: Nombre del cliente.
# 8. Segment: Clasificación de segmentos del cliente.
# 9. City: Ciudad donde se realizó la venta.
# 10. State: Estado donde se realizó la venta.
# 11. Country: País donde se realizó la venta.
# 12. Postal Code: Código postal donde se realizó la venta.
# 13. Region: Región geográfica donde se realizo la venta.
# 14. Product ID: Identificador único para cada producto.
# 15. Category: Clasificación de categoría del producto.
# 16. Sub-Category: Clasificación por subcategorías el producto.
# 17. Product Name: Nombre del producto.
# 18. Sales: Importe total de ventas del pedido
# 19. Quantity: Cantidad de productos vendidos en el pedido.
# 20. Discount: Descuento aplicado al pedido.
# 21. Profit: Beneficio generado por el pedido.
# 22. Shipping Cost: Costo de envío.
# 23. Order Priority: Prioridad de pedido.
#
# * La columna 'Row ID' se puede eliminar, al ser un identificador de columna.
# * Las columnas 'Order date' y 'Ship date' se deben convertir a un objeto datetime.

# %% [markdown]
# ## Manejo de valores nulos y duplicados

# %% [markdown]
# ### Valores faltantes

# %%
data.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
# Calcular el porcentaje de valores nulos en la columna Postal Code
print(f"{data['Postal Code'].isnull().sum() / len(data) * 100:.2f}%")
# Out:
# 80.51%

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# * La columna Postal Code tiene un alto porcentaje de valores faltantes (80,5%). Lo que genera falta de información en la ubicación geográfica de los clientes, que puede ser complementada por las columnas 'Country', 'State' y 'City'. Dando la posibilidad de eliminar la columna 'Postal Code'.
# Esta columna es irrelevante en el análisis, ya que no aporta información significativa, se sugiere eliminarla.
# * No se encuentran valores duplicados en el conjunto de datos.

# %% [markdown]
# ## Análisis estadístico descriptivo

# %%
print(data.describe())
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375915
# std      174.340972      57.296804
# min    -6599.978000       0.000000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# max     8399.976000     933.570000

# %%
# Filtro para las filas con valores negativos
profit_neg = data[data['Discount'] >= 0.48][["Discount", "Sales", "Profit"]]
profit_neg[profit_neg["Profit"] > 0]
# Out:
# Empty DataFrame
# Columns: [Discount, Sales, Profit]
# Index: []

# %%
# Lista con los valores negativos
profit_neg = data[data['Discount'] >= 0.48][["Discount", "Sales", "Profit"]]
profit_neg1 = [x for x in profit_neg["Profit"] if x > 0]
len(profit_neg1)
# Out:
# 0

# %% [markdown]
# * Postal Code contiene 41296 datos faltantes, la media es de 55.190,38, y la desviación estandar es alta (32.063,69), lo que sugiere que hay mucha variabilidad en los códigos postales.
#
# * Sales tiene un valor mínimo de 0,44 y un máximo de 22.638,480. La media es de 246,49 y la desviación estandar de 487,56 lo que índica una gran dispersión en los datos. El 25% de las ventas estan por debajo de 30,75, el 50% por debajo de 85,053 y el 75% por debajo de 251,0532 pero tiene un valor máximo de 22638.48 lo que sugiere la presencia de valores atípicos.
#
# * Quantity la media es de 3,47, la mediana de 3 y el 75% de los valores estan por debajo de 5.
#
# * Las columnas 'Order Data' y 'Ship Date' son de tipo object, pero contienen dato tipo fecha. Es necesario convertir su tipo de dato a datetime.
#
# * La columna 'Profit' representa el beneficio generado por cada pedido. Sin embargo, contiene valores negativos, lo que podria indicar un error en los datos o reflejar pérdidas ocasionadas por devoluciones. La media es de 28,61 y la std de 174,34 mucho más alta que la media, indica gran dispersión. el 75% de los datos esta por debajo de 36.810000 pero el valor máximo es de 8399.976000, posibles valores atípicos.
#
# * Los valores negativos en la columna 'Profit' estan relacionados con los descuentos superiores de 0.47 en las ventas. Posiblemente esto se debe a que la cantidad descontada supera el margen de ganancia de los productos.
#
# * Shipping Cost, la media es de 26.37 y la std es de 57.29, índica alta dispersión. El 75% de los datos esta por debajo de 24.45 y el valor máximo es de 933.57, posibles valores atípicos.

# %% [markdown]
# ### Transformando a objetos datetime

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'], format='%d-%m-%Y')
data['Ship Date'] = pd.to_datetime(data['Ship Date'], format='%d-%m-%Y')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
#  17  Product Name    51290 non-null  object
#  18  Sales           51290 non-null  float64
#  19  Quantity        51290 non-null  int64
#  20  Discount        51290 non-null  float64
#  21  Profit          51290 non-null  float64
#  22  Shipping Cost   51290 non-null  float64
#  23  Order Priority  51290 non-null  object
# dtypes: datetime64[ns](2), float64(5), int64(2), object(15)
# memory usage: 9.4+ MB

# %%
data.select_dtypes(['int64', 'float64']).columns
# Out:
# Index(['Row ID', 'Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost'],
#       dtype='object')

# %%
# Definiendo las columnas y las filas 
rows, cols = 2, 4

# Creando la cuadricula y la figura
fig, ax = plt.subplots(rows, cols, figsize=(15, 15))
ax = ax.flatten()

for i, col in enumerate(data.select_dtypes(['int64', 'float64']).columns):
    sns.histplot(data[col], ax=ax[i], kde=True)
    ax[i].set_title(f"Histrograma de {col}")
    # Calcular la asimetría y curtosis
    skewness = data[col].skew() # Grado de asimetría, valor 0 distribución normal
    kurtosis = data[col].kurtosis() # grado de aputamiento, +++ leptocúrtica, --- platicúrtica
    ax[i].annotate(f'Skewness: {skewness:.2f}\nKurtosis: {kurtosis:.2f}', xy=(0.55, 0.90), xycoords='axes fraction', fontsize=10, color='red')

for j in range(len(data.select_dtypes(['int64', 'float64']).columns), len(ax)):
    ax[j].set_visible(False) # Oculta los gráficos vacíos
    
plt.tight_layout()
plt.show()

# %%
# Definiendo cantidad de columnas y filas
rows, cols = 2, 4

# Creando la cuadricula y el gráfico
fig, ax = plt.subplots(rows, cols, figsize=(15, 15))
ax = ax.flatten()

# Definiendo solo las columnas numéricas
columns_numerics = data.select_dtypes(['int64', 'float64']).columns

# Creando los gráficos de dispersión
for i, col in enumerate(columns_numerics):
    sns.scatterplot(data[col], ax=ax[i])

# Eliminar figuras vacias
for j in range(len(columns_numerics), len(ax)):
    ax[j].set_visible(False)
    
        
plt.tight_layout()
plt.show()

# %% [markdown]
# * Sales: Una asimetría alta de 8,14, lo que índica que la distribución esta fuertemente sesgada hacia la derecha y la mayoria de valores están en el extremo izquierdo, con pocos valores extremadamente altos que arrastran la media hacia la derecha y una curtosis extremadamente alta de 176,73 que índica que los valores estan inusualmente concentrados cerca de la media y colas muy largas, lo que siguiere la presencia de valores atípicos. Lo que podria sugerir errores en los datos o una distribución muy sesgada. Se sugiere una transformación de los datos, un cambio de escala (logaritmico, raíz cuadrada o Box-Cox) debido a que la asimetría tiene un valor extremadamente alto y una normalización.
#
# * Quantity: Una asimetría de 1,36 lo que sugiere una asimetría moderada. Se recomienda transformar los datos para normalizarlos.
#
# * Discount: Una asimetría moderada con un valor de 1.39, se recomienda transformar los datos para normalizarlos. La curtosis tiene tendencia platicúrtica con un valor de 0.72.La distribución cuenta con valores extremos a la derecha.
#
# * Profit: Una asimetría alta a la derecha con un valor de 4.16. La curtosis extremadamente alta con un valor de 291.41 sugiere que los valores estan inusualmente concentrados alrededor de la media y una concentración alta de valores atipícos en los extremos. Se recomienda transformar los datos a través de un escalamiento (logaritmico, raíz cuadrada o Box-Cox) para corregir la asimetría y debido a que la curtosis es extremadamente alta, los valores atípicos estan influyendo fuertemente en la distribución, se recomienda suavizarlos o eliminarlos.
#
# * Shipping Cost: Una asimetría alta a la derecha con un valor de 5.86 y una curtosis leptocúrtica con colas gruesas que sugieren una concentración alta de valores atípicos en los extremos. Se recomienda aplicar transformación de datos con Box-Cox, escalamiento o normalización.

# %%
# Seleccionar variables numéricas
numeric_cols = data.select_dtypes(['int64', 'float64']).columns

# %% [markdown]
# * Se hace evidente la gran acumulación de valores atípicos en los extremos en las característica 'Sales', 'Profit' y Shipping Cost. Se recomienda detectar y tratar los valores atípicos usando técnicas como el rango intercuartílico(IQR) o el Z-Score para identificar, y ajustar o eliminar los valores extremos.

# %% [markdown]
# ## Análisis de variables categóricas

# %% [markdown]
# ### Frecuencia de cada categoría

# %%
# Seleccionar variables categóricas
variables_categoricas = data.select_dtypes(['object'])

# %%
# Creando nuevo dataframe agrupando los datos por ciudad y contando cuantos clientes hay por País
ventas_pais = data.groupby('Country')["Customer ID" ].count().reset_index()
# Renombrando columnas
ventas_pais.columns = ["Country", "Frecuencia"]
# Ordenando valores
ventas_pais = ventas_pais.sort_values(by="Frecuencia", ascending=False)

# Creando gráfico de barras
color = sns.color_palette("pastel", n_colors=10)
plt.figure(figsize=(15,10))
sns.barplot(data=ventas_pais.head(10), x="Country", y="Frecuencia", hue="Country")
plt.show()

# %%
for col in variables_categoricas.columns:
    val_uni = data[col].unique().tolist()
    print(val_uni)
# Out:
# ['CA-2012-124891', 'IN-2013-77878', 'IN-2013-71249', 'ES-2013-1579342', 'SG-2013-4320', 'IN-2013-42360', 'IN-2011-81826', 'IN-2012-86369', 'CA-2014-135909', 'CA-2012-116638', 'CA-2011-102988', 'ID-2012-28402', 'SA-2011-1830', 'MX-2012-130015', 'IN-2013-73951', 'ES-2014-5099955', 'CA-2014-143567', 'ES-2014-1651774', 'IN-2014-11763', 'TZ-2014-8190', 'PL-2012-7820', 'CA-2011-154627', 'IN-2011-44803', 'ES-2013-2860574', 'US-2014-133193', 'MX-2014-165309', 'IN-2011-10286', 'ES-2011-4699
# ['New York City', 'Wollongong', 'Brisbane', 'Berlin', 'Dakar', 'Sydney', 'Porirua', 'Hamilton', 'Sacramento', 'Concord', 'Alexandria', 'Kabul', 'Jizan', 'Toledo', 'Mudanjiang', 'Paris', 'Henderson', 'Prato', 'Townsville', 'Uvinza', 'Bytom', 'Chicago', 'Suzhou', 'Edinburgh', 'Juárez', 'Soyapango', 'Taipei', 'Leipzig', 'Los Angeles', 'Surat', 'Santo Domingo', 'Saint-Brieuc', 'Amarillo', 'Gold Coast', 'Fresno', 'Kamina', 'Burlington', 'Stockton-on-Tees', 'Mataram', 'Gorakhpur', 'Thiruvananthapuram', 'Huddersfield', 'Minneapolis', 'Montreuil', 'Shouguang', 'Jamshedpur', 'Paysandú', 'Behshahr', 'Huntington Beach', 'Maputo', 'Bhopal', 'Seattle', 'Delhi', 'Geraldton', 'Tallahassee', 'Dhaka', 'Munster', 'Celle', 'Wuxi', 'Richmond', 'Seville', 'Raipur', 'Gómez Palacio', 'Kharkiv', 'Jinan', 'Chinandega', 'Kananga', 'Palembang', 'London', 'Melbourne', 'Atlanta', 'Duisburg', 'Nanchong', 'Naihati', 'Lille', 'Meknes', 'Jackson', 'Philadelphia', 'Krefeld', 'Bandung', 'Casablanca', 'Tongi', 'Montréal', 'Manila', 'Newcastle', 'Graz', 'Nowra', 'Boulogne-Billancourt', 'Malakoff', 'Kinshasa', 'Perth', 'Le Bouscat', 'Puebla', 'Augsburg', 'Nice', 'Medellín', 'Bergen op Zoom', 'Lakewood', 'Hanover', 'Vigo', 'Gaoyou', 'Bremen', 'Muret', 'Zigong', 'Adelaide', 'Detroit', 'Chelles', 'Kuantan', 'Harrisonburg', 'Everett', 'Quito', 'Vadodara', 'Sanya', 'Bangkok', 'San Diego', 'Tasikmalaya', 'Guaymas', 'Wuhan', 'Madison', 'Salto', 'Treviso', 'Hargeysa', 'Long Beach', 'Yogyakarta', 'Anshan', 'Amsterdam', 'Le Petit-Quevilly', 'Bochum', 'Hamburg', 'Houston', 'Mixco', 'Yonkers', 'Morelia', 'Changchun', 'Madrid', 'Jeddah', 'Norman', 'Medan', 'Jakarta', 'Lancaster', 'Surakarta', 'Beijing', 'Tulancingo', 'Brest', 'Valencia', 'Charlotte', 'Zhytomyr', 'Argenteuil', 'Talence', 'Aurangabad', 'Plaisir', 'Harrogate', 'Phnom Penh', 'Mackay', 'North Las Vegas', 'Jambi', 'Moers', 'Newark', 'Shenzhen', 'Launceston', 'Marikina', 'Johannesburg', 'Barakaldo', 'Providence', 'Qingdao', 'San Francisco', 'Shiraz', 'Bokaro', 'Fuji', 'Benidorm', 'Kozhikode', 'Kuala Lumpur', "Astrakhan'", 'Columbus', 'Xiangtan', 'Shaoxing', 'Jabalpur', 'Patna', 'La Baule-Escoublac', 'Dijon', 'Cape Town', 'Cairo', 'West Bromwich', 'Baku', 'Burnley', 'Laval', 'Vilnius', 'Buenos Aires', 'Girga', 'Kochi', 'Maseru', 'Wellington', 'Luoyang', 'Feira de Santana', 'Matagalpa', 'Virginia Beach', 'Managua', 'Wuhai', 'Nantes', 'Strasbourg', 'Surabaya', 'Tupã', 'Vienna', 'Mexico City', 'Hobart', 'Hirakata', 'Preston', 'Agra', 'Granollers', 'Ho Chi Minh City', 'Camagüey', 'Morristown', 'Piatra-Neamt', 'Milpa Alta', 'León', 'Izmir', 'Coyoacán', 'Manukau City', 'Yaounde', 'Newcastle upon Tyne', 'Dehra Dun', 'Santander', 'Cangzhou', 'Shanghai', 'Rybinsk', 'Ibiúna', 'Canberra', 'Port Elizabeth', 'Cambridge', 'Kota', 'Christchurch', 'Vincennes', 'Chongqing', 'Gyula', 'Lucknow', 'Florence', 'Turin', 'Springfield', 'Singapore', 'Benguela', 'Lafayette', 'Himeji', 'Kendari', 'Mejicanos', 'Barcelona', 'Menton', 'Huntsville', 'Clermont-Ferrand', 'Buzau', 'Bayeux', 'San Antonio', 'Darwin', 'Jamestown', 'Lens', 'Lannion', 'Iserlohn', 'Kalemie', 'Ghent', 'Indianapolis', 'Marseille', 'Lahore', 'Grenoble', 'Espoo', 'Whyalla', 'Ivry-sur-Seine', 'Kanpur', 'Saint-Laurent-du-Var', 'Cartagena', 'Cancún', 'Harbin', 'Kumasi', 'Salem', 'Angers', 'Khorramabad', 'Chennai', 'Barletta', 'Tamworth', 'Kulti', 'Le Mans', 'Mianyang', 'Cadereyta', 'Bundaberg', 'Valparaíso de Goiás', 'Manado', 'Muzaffarpur', 'Kermanshah', 'Thane', 'Piedecuesta', 'Bangalore', 'Xiamen', 'Kitwe', 'Jieyang', 'Hamamatsu', 'Ningbo', 'Jodhpur', 'Weimar', 'Auckland', 'Lubumbashi', 'Franklin', 'Omaha', 'Nagpur', 'Villahermosa', 'Oyonnax', 'Metepec', 'Santa Ana', 'Antony', 'Culiacán', 'Mobile', 'Al Amarah', 'Mashhad', 'Bhavnagar', 'Rome', 'Palma de Mallorca', 'Saint-Priest', 'Gyor', 'Monrovia', 'Santiago de Cuba', 'Bogotá', 'Erlangen', 'Tbilisi', 'Jaipur', "Reggio nell'Emilia", 'Azcapotzalco', 'Lublin', 'Zurich', 'Elbasan', 'Voronezh', 'Shimonoseki', 'Palu', 'Imphal', 'Shen ...
# ['New York', 'New South Wales', 'Queensland', 'Berlin', 'Dakar', 'Wellington', 'Waikato', 'California', 'North Carolina', 'Virginia', 'Kabul', 'Jizan', 'Parana', 'Heilongjiang', 'Ile-de-France', 'Kentucky', 'Tuscany', 'Kigoma', 'Silesia', 'Illinois', 'Anhui', 'Scotland', 'Chihuahua', 'San Salvador', 'Taipei City', 'Saxony', 'Gujarat', 'Santo Domingo', 'Brittany', 'Texas', 'Katanga', 'England', 'Nusa Tenggara Barat', 'Haryana', 'Kerala', 'Minnesota', 'Shandong', 'Jharkhand', 'Paysandú', 'Mazandaran', 'Cidade De Maputo', 'Madhya Pradesh', 'Washington', 'Delhi', 'Western Australia', 'Florida', 'Dhaka', 'Lower Saxony', 'Jiangsu', 'Andalusía', 'Uttarakhand', 'Durango', 'Kharkiv', 'Chinandega', 'Kasai-Occidental', 'Sumatera Selatan', 'Victoria', 'Georgia', 'North Rhine-Westphalia', 'Sichuan', 'West Bengal', 'Nord-Pas-de-Calais', 'Meknès-Tafilalet', 'Michigan', 'Pennsylvania', 'Jawa Barat', 'Grand Casablanca', 'Nevada', 'Quebec', 'National Capital', 'Styria', 'Kinshasa', 'Aquitaine', 'Puebla', 'Bavaria', "Provence-Alpes-Côte d'Azur", 'Antioquia', 'North Brabant', 'New Jersey', 'Galicia', 'Bremen', 'Midi-Pyrénées', 'South Australia', 'Pahang', 'Massachusetts', 'Pichincha', 'Hainan', 'Bangkok', 'Sonora', 'Hubei', 'Wisconsin', 'São Paulo', 'Veneto', 'Woqooyi Galbeed', 'Yogyakarta', 'Liaoning', 'North Holland', 'Upper Normandy', 'Hamburg', 'Guatemala', 'Michoacán', 'Jilin', 'Madrid', 'Makkah', 'Oklahoma', 'Sumatera Utara', 'Jakarta', 'Ohio', 'Jawa Tengah', 'Beijing', 'Hidalgo', 'Brest', 'Valenciana', 'Zhytomyr', 'Bihar', 'Phnom Penh', 'Jambi', 'Delaware', 'Guangdong', 'Tasmania', 'Gauteng', 'Basque Country', 'Rhode Island', 'Fars', 'Shizuoka', 'Kuala Lumpur', "Astrakhan'", 'Hunan', 'Zhejiang', 'Pays de la Loire', 'Burgundy', 'Western Cape', 'Al Qahirah', 'Baki', 'Vilnius', 'Buenos Aires', 'Suhaj', 'Maseru', 'Henan', 'Bahia', 'Matagalpa', 'Managua', 'Inner Mongolia', 'Alsace', 'Jawa Timur', 'Vienna', 'Distrito Federal', 'Osaka', 'Uttar Pradesh', 'Catalonia', 'Ho Chí Minh City', 'Camagüey', 'Neamt', 'Guanajuato', 'Izmir', 'Auckland', 'Centre', 'Cantabria', 'Hebei', 'Shanghai', 'León', "Yaroslavl'", 'Australian Capital Territory', 'Eastern Cape', 'Chhattisgarh', 'Canterbury', 'Chongqing', 'Bekes', 'Piedmont', 'Missouri', 'Singapore', 'Benguela', 'Indiana', 'Hyogo', 'Sulawesi Tenggara', 'Alabama', 'Auvergne', 'Buzau', 'Paraíba', 'Northern Territory', 'Lower Normandy', 'East Flanders', 'Punjab', 'Rhône-Alpes', 'Uusimaa', 'Bolívar', 'Quintana Roo', 'Ashanti', 'Tamil Nadu', 'Lorestan', 'Apulia', 'Nuevo León', 'Goiás', 'Sulawesi Utara', 'Kermanshah', 'Maharashtra', 'Santander', 'Karnataka', 'Fujian', 'Copperbelt', 'Rajasthan', 'Thuringia', 'Nebraska', 'Tabasco', 'México', 'Sinaloa', 'Maysan', 'Razavi Khorasan', 'Lazio', 'Balearic Islands', 'Gyor', 'Montserrado', 'Santiago de Cuba', 'Bogota', 'Tbilisi', 'Gansu', 'Emilia-Romagna', 'Lublin', 'Zürich', 'Elbasan', 'Voronezh', 'Yamaguchi', 'Sulawesi Tengah', 'Manipur', 'Mandoul', 'Podgorica', 'Jalisco', 'Ontario', 'Hamadan', 'Khomas', 'Quezaltenango', 'La Libertad', 'Guantánamo', 'Western Visayas', 'Louisiana', 'Lisboa', 'San Juan', 'Analamanga', 'Bashkortostan', 'Tehran', 'Baluchistan', 'Cundinamarca', 'Volyn', 'Utah', 'Northland', 'Yunnan', 'British Columbia', 'Navarra', 'Stockholm', 'Asturias', 'Campania', 'Poltava', 'Andhra Pradesh', 'North-West', 'Vladimir', 'Castile and León', 'Yangon', 'Saint Catherine', 'Tianjin', 'Barahona', 'Federal District', 'Ad Dawhah', 'Oita', 'Bay of Plenty', 'Rio Grande do Norte', 'Languedoc-Roussillon', 'Hesse', 'Santa Catarina', 'New Hampshire', 'Yucatán', 'Dar Es Salaam', 'Tadla-Azilal', 'Niari', 'Kaliningrad', 'Vest-Agder', 'Al Qadisiyah', 'Arizona', 'Mayabeque', 'Alger', 'Istanbul', 'Kaunas', 'Ardabil', 'Baja California', 'Al Iskandariyah', 'Guangxi', 'Mecklenburg-Vorpommern', 'Trentino-Alto Adige', 'Basel-Stadt', 'Maputo', 'Poitou-Charentes', 'Seoul', 'Lombardy', 'Sabah', 'Colorado', 'Minas Gerais', 'Benue', 'Harjumaa', 'Wales', 'Kalimantan Timur', 'Balikesir', ' ...
# ['United States', 'Australia', 'Germany', 'Senegal', 'New Zealand', 'Afghanistan', 'Saudi Arabia', 'Brazil', 'China', 'France', 'Italy', 'Tanzania', 'Poland', 'United Kingdom', 'Mexico', 'El Salvador', 'Taiwan', 'India', 'Dominican Republic', 'Democratic Republic of the Congo', 'Indonesia', 'Uruguay', 'Iran', 'Mozambique', 'Bangladesh', 'Spain', 'Ukraine', 'Nicaragua', 'Morocco', 'Canada', 'Philippines', 'Austria', 'Colombia', 'Netherlands', 'Malaysia', 'Ecuador', 'Thailand', 'Somalia', 'Guatemala', 'Belarus', 'Cambodia', 'South Africa', 'Japan', 'Russia', 'Egypt', 'Azerbaijan', 'Lithuania', 'Argentina', 'Lesotho', 'Vietnam', 'Cuba', 'Romania', 'Turkey', 'Cameroon', 'Hungary', 'Singapore', 'Angola', 'Belgium', 'Pakistan', 'Finland', 'Ghana', 'Zambia', 'Iraq', 'Liberia', 'Georgia', 'Switzerland', 'Albania', 'Chad', 'Montenegro', 'Namibia', 'Portugal', 'Madagascar', 'Sweden', 'Myanmar (Burma)', 'Jamaica', 'Qatar', 'Republic of the Congo', 'Norway', 'Algeria', 'South Korea', 'Nigeria', 'Estonia', "Cote d'Ivoire", 'Honduras', 'Paraguay', 'Czech Republic', 'Central African Republic', 'Benin', 'Bolivia', 'Chile', 'Martinique', 'Syria', 'Lebanon', 'Kenya', 'Mali', 'Libya', 'Venezuela', 'Trinidad and Tobago', 'Ireland', 'Bulgaria', 'Panama', 'Israel', 'Haiti', 'Barbados', 'Slovenia', 'Togo', 'Mauritania', 'Guinea', 'Rwanda', 'Denmark', 'Niger', 'Papua New Guinea', 'Mongolia', 'Sudan', 'Peru', 'Sierra Leone', 'Bosnia and Herzegovina', 'Guinea-Bissau', 'Djibouti', 'Tunisia', 'Croatia', 'Hong Kong', 'Nepal', 'Guadeloupe', 'Kyrgyzstan', 'Zimbabwe', 'Uzbekistan', 'South Sudan', 'Gabon', 'Bahrain', 'Yemen', 'Jordan', 'United Arab Emirates', 'Moldova', 'Swaziland', 'Turkmenistan', 'Kazakhstan', 'Ethiopia', 'Uganda', 'Slovakia', 'Sri Lanka', 'Tajikistan', 'Burundi', 'Macedonia', 'Eritrea', 'Equatorial Guinea', 'Armenia']
# ['US', 'APAC', 'EU', 'Africa', 'EMEA', 'LATAM', 'Canada']
# ['East', 'Oceania', 'Central', 'Africa', 'West', 'South', 'Central Asia', 'EMEA', 'North Asia', 'North', 'Caribbean', 'Southeast Asia', 'Canada']
# ['TEC-AC-10003033', 'FUR-CH-10003950', 'TEC-PH-10004664', 'TEC-PH-10004583', 'TEC-SHA-10000501', 'TEC-PH-10000030', 'FUR-CH-10004050', 'FUR-TA-10002958', 'OFF-BI-10003527', 'FUR-TA-10000198', 'OFF-SU-10002881', 'FUR-TA-10001889', 'TEC-CIS-10001717', 'FUR-CH-10002033', 'OFF-AP-10003500', 'OFF-AP-10000423', 'TEC-AC-10004145', 'OFF-AP-10004512', 'TEC-CO-10000865', 'OFF-KIT-10004058', 'FUR-HON-10000224', 'TEC-PH-10001363', 'FUR-CH-10000027', 'OFF-AP-10003590', 'TEC-PH-10004182', 'FUR-TA-10002827', 'FUR-TA-10004744', 'TEC-PH-10002885', 'FUR-CH-10001415', 'TEC-PH-10002815', 'TEC-MA-10000161', 'FUR-CH-10002024', 'OFF-AP-10004246', 'FUR-TA-10003473', 'TEC-APP-10000308', 'TEC-MA-10003979', 'TEC-MA-10004125', 'TEC-CO-10000013', 'TEC-PH-10000499', 'TEC-PH-10003856', 'FUR-BO-10004852', 'OFF-AP-10000486', 'OFF-BI-10001120', 'FUR-CH-10003365', 'FUR-CH-10000602', 'TEC-MA-10002680', 'FUR-CH-10000891', 'TEC-CAN-10003392', 'TEC-CO-10001449', 'FUR-BO-10001372', 'TEC-MOT-10002272', 'TEC-CO-10004997', 'TEC-CO-10001766', 'FUR-TA-10000226', 'OFF-AP-10002244', 'TEC-PH-10001459', 'FUR-BO-10001073', 'TEC-MA-10000045', 'TEC-PH-10002035', 'TEC-PH-10002565', 'OFF-AP-10002945', 'FUR-BO-10004999', 'FUR-TA-10001205', 'TEC-PH-10004196', 'FUR-CHR-10001018', 'FUR-CH-10003232', 'OFF-AP-10001630', 'FUR-HAR-10002873', 'FUR-TA-10000687', 'TEC-PH-10004505', 'TEC-PH-10002683', 'TEC-CO-10002269', 'TEC-CO-10002526', 'FUR-CH-10002891', 'TEC-CAN-10001437', 'OFF-BI-10004995', 'TEC-PH-10004327', 'OFF-AP-10001621', 'OFF-HOO-10001881', 'TEC-CO-10001954', 'FUR-BO-10003282', 'TEC-CO-10003102', 'FUR-TA-10003392', 'OFF-AP-10002552', 'TEC-MOT-10000554', 'FUR-TA-10003627', 'FUR-BO-10001133', 'TEC-MA-10003515', 'OFF-AP-10002904', 'TEC-MOT-10003348', 'TEC-PH-10001990', 'TEC-PH-10002898', 'TEC-CO-10001633', 'TEC-PH-10002623', 'FUR-TA-10004575', 'FUR-BO-10001498', 'OFF-AP-10003598', 'FUR-CH-10001582', 'TEC-MA-10001047', 'TEC-PH-10000505', 'FUR-BO-10002003', 'TEC-CO-10001775', 'OFF-AP-10000647', 'TEC-MA-10004002', 'TEC-CO-10001926', 'OFF-ST-10001496', 'FUR-CH-10002203', 'FUR-BO-10001934', 'TEC-CO-10000562', 'TEC-MA-10001127', 'OFF-BI-10000545', 'TEC-CO-10002035', 'TEC-CO-10004099', 'TEC-PH-10003002', 'FUR-TA-10001932', 'TEC-CO-10004722', 'FUR-CH-10000749', 'TEC-CO-10004398', 'TEC-CO-10004535', 'TEC-AC-10000420', 'FUR-BO-10001212', 'TEC-PH-10001670', 'FUR-CH-10001215', 'FUR-BO-10004679', 'OFF-AP-10001776', 'TEC-MA-10003704', 'FUR-CH-10001854', 'TEC-MA-10000984', 'TEC-AC-10000376', 'TEC-CO-10003800', 'TEC-SAM-10004230', 'FUR-CH-10002320', 'OFF-AP-10002312', 'TEC-PH-10000169', 'FUR-CH-10000595', 'FUR-BO-10000288', 'TEC-AC-10000866', 'OFF-AP-10001623', 'FUR-BO-10003541', 'TEC-CO-10004365', 'TEC-MA-10000822', 'TEC-PH-10000800', 'FUR-BO-10004834', 'FUR-TA-10001642', 'OFF-AP-10001041', 'OFF-AP-10002090', 'OFF-AP-10002330', 'TEC-CIS-10002344', 'FUR-TA-10002153', 'OFF-AP-10004964', 'TEC-AC-10003832', 'FUR-CH-10002061', 'TEC-PH-10002759', 'TEC-PH-10001699', 'TEC-MA-10000418', 'TEC-PH-10001494', 'FUR-BO-10000490', 'TEC-PH-10000018', 'FUR-HON-10003533', 'TEC-AC-10001949', 'OFF-HOO-10004910', 'TEC-MA-10001335', 'FUR-TA-10000347', 'TEC-PH-10000493', 'FUR-TA-10003596', 'FUR-TA-10003179', 'TEC-PH-10001396', 'FUR-TA-10003078', 'FUR-CH-10003581', 'FUR-TA-10000184', 'OFF-AP-10001956', 'TEC-PH-10002200', 'OFF-AP-10003382', 'OFF-ST-10002011', 'OFF-AP-10003917', 'OFF-ST-10002900', 'TEC-CO-10003819', 'OFF-AP-10000675', 'FUR-BO-10003404', 'OFF-AP-10001824', 'OFF-SME-10000746', 'TEC-MA-10003673', 'OFF-ST-10001490', 'TEC-PH-10001578', 'TEC-CO-10000208', 'FUR-CH-10003312', 'TEC-EPS-10000053', 'OFF-ST-10004060', 'TEC-PH-10000303', 'FUR-BO-10002708', 'FUR-BO-10000210', 'FUR-BO-10001192', 'FUR-SAU-10002255', 'FUR-CH-10000974', 'OFF-AP-10003866', 'FUR-CH-10003616', 'FUR-CH-10000479', 'TEC-CO-10001046', 'OFF-HOO-10000318', 'TEC-NOK-10001283', 'OFF-AP-10000407', 'OFF-BI-10001359', 'FUR-CH-10002335', 'TEC-MA-10001148', 'FUR-BAR-10004434', 'FUR-BO-10002444', 'FUR-BO-10004709', 'TEC-MA-10004772', 'FUR-BAR-10003532', 'TEC ...
# ['Technology', 'Furniture', 'Office Supplies']
# ['Accessories', 'Chairs', 'Phones', 'Copiers', 'Tables', 'Binders', 'Supplies', 'Appliances', 'Machines', 'Bookcases', 'Storage', 'Furnishings', 'Art', 'Paper', 'Envelopes', 'Fasteners', 'Labels']
# ['Plantronics CS510 - Over-the-Head monaural Wireless Headset System', 'Novimex Executive Leather Armchair, Black', 'Nokia Smart Phone, with Caller ID', 'Motorola Smart Phone, Cordless', 'Sharp Wireless Fax, High-Speed', 'Samsung Smart Phone, with Caller ID', 'Novimex Executive Leather Armchair, Adjustable', 'Chromcraft Conference Table, Fully Assembled', 'Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind', 'Chromcraft Bull-Nose Wood Oval Conference Tables & Bases', 'Martin Yale Chadless Opener Electric Letter Opener', 'Bevis Conference Table, Fully Assembled', 'Cisco Smart Phone, with Caller ID', 'Harbour Creations Executive Leather Armchair, Adjustable', 'KitchenAid Microwave, White', 'Breville Refrigerator, Red', 'Logitech diNovo Edge Keyboard', 'Hoover Stove, Red', 'Brother Fax Machine, High-Speed', 'KitchenAid Stove, White', 'Hon Computer Table, with Bottom Storage', 'Apple iPhone 5S', 'SAFCO Executive Leather Armchair, Black', 'KitchenAid Refrigerator, Black', 'Motorola Smart Phone, Full Size', 'Hon Computer Table, Fully Assembled', 'Lesro Conference Table, with Bottom Storage', 'Apple iPhone 5', 'Office Star Executive Leather Armchair, Red', 'Samsung Smart Phone, VoIP', 'Okidata Inkjet, Wireless', 'HON 5400 Series Task Chairs for Big and Tall', 'Breville Stove, Red', 'Bretford Rectangular Conference Table Tops', 'Apple Smart Phone, Full Size', 'Ativa V4110MDD Micro-Cut Shredder', 'Cubify CubeX 3D Printer Triple Head Print', 'Brother Fax Machine, Laser', 'Motorola Smart Phone, with Caller ID', 'Sauder Classic Bookcase, Traditional', 'Cuisinart Stove, Silver', 'Ibico EPK-21 Electric Binding System', 'Office Star Executive Leather Armchair, Adjustable', 'Novimex Executive Leather Armchair, Red', 'Konica Inkjet, White', 'Harbour Creations Executive Leather Armchair, Black', 'Canon Copy Machine, Color', 'Hewlett Packard LaserJet 3310 Copier', 'Safco Classic Bookcase, Pine', 'Hewlett Wireless Fax, Color', 'Canon PC940 Copier', 'Chromcraft Conference Table, with Bottom Storage', 'Breville Refrigerator, White', 'Samsung Galaxy Mega 6.3', 'Safco Classic Bookcase, Metal', 'Zebra ZM400 Thermal Label Printer', 'Samsung Smart Phone, Cordless', 'Apple Audio Dock, with Caller ID', "Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room", 'Chromcraft Wood Table, Rectangular', 'Chromcraft Round Table, Rectangular', 'Hamilton Beach Microwave, Black', 'Bevis Conference Table, with Bottom Storage', 'Nokia Smart Phone, Full Size', 'Apple Smart Phone, Cordless', 'Brother Ink, Color', 'Sharp Wireless Fax, Digital', 'Hon Executive Leather Armchair, Adjustable', 'Canon Wireless Fax, Laser', 'GBC DocuBind P400 Electric Binding System', 'Hamilton Beach Refrigerator, Black', 'Hoover Stove, White', 'Brother Wireless Fax, Laser', 'Ikea Classic Bookcase, Mobile', 'Global Adaptabilities Conference Tables', 'Hamilton Beach Stove, White', 'Panasonic Printer, Red', 'Hamilton Beach Refrigerator, Silver', 'Cisco Smart Phone, Full Size', 'Samsung Smart Phone, Full Size', 'Sharp Fax Machine, High-Speed', 'Hon 5100 Series Wood Tables', 'Dania Classic Bookcase, Pine', 'Office Star Executive Leather Armchair, Black', '3D Systems Cube Printer, 2nd Generation, Magenta', 'Apple Smart Phone, with Caller ID', 'Sauder Classic Bookcase, Metal', 'Sharp Wireless Fax, Laser', 'Hoover Refrigerator, White', 'Zebra GX420t Direct Thermal/Thermal Transfer Printer', 'Hewlett Wireless Fax, Laser', 'Standard Rollaway File with Lock', 'Bush Library with Doors, Metal', 'HP Wireless Fax, Digital', 'HP Designjet T520 Inkjet Large Format Printer - 24" Color', 'GBC Ibimaster 500 Manual ProClick Binding System', 'Canon Wireless Fax, High-Speed', 'Sharp Fax Machine, Digital', 'Chromcraft 48" x 96" Racetrack Double Pedestal Table', 'Canon imageCLASS 2200 Advanced Copier', 'Office Star - Ergonomic Mid Back Chair with 2-Way Adjustable Arms', 'Brother Copy Machine, Color', 'Hewlett Fax Machine, High-Speed', 'Belkin Router, USB', 'Safco Classic Bookcase, ...
# ['Critical', 'Medium', 'High', 'Low']

# %%
rows = 2
cols = 2

fig, ax = plt.subplots(rows, cols, figsize=(15, 15))
ax = ax.flatten()

categorias = ["Category", "Sub-Category", "Region"]
colors = sns.color_palette("bright")

for i, col in enumerate(categorias):
    ax[i].pie(data[col].value_counts().tolist(), 
              labels=data[col].value_counts().index,
              colors=colors,
              autopct="%0.0f%%", # Cadena de formato que específica cómo mostrar los valores
              shadow="True",
              #startangle=90,
              #textprops={"color": "Green", "fontsize": 16},
              wedgeprops={"linewidth": 6},
              #frame="true",
              center=(0.1, 0.1),
              #rotatelabels="true"
            )
    
for j in range(len(categorias), len(ax)):
  ax[j].set_visible(False)
    
plt.show()

# %% [markdown]
# ## Identificación de valores atípicos

# %%
df_numeric = pd.DataFrame()

for column in numeric_cols:
    df_numeric[column] = data[column]

# %% [markdown]
# ### Diagramas de caja

# %%
# Definiendo cantidad de columnas y filas 
rows, cols = 2, 4

# Creando la cuadricula y la figura
fig, ax = plt.subplots(rows, cols, figsize=(15, 15))
ax = ax.flatten()


for i, col in enumerate(numeric_cols):
    sns.boxplot(data[col], ax=ax[i])

for j in range(len(numeric_cols), len(ax)):
    ax[j].set_visible(False)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Calculos de rango intercuartil (IQR)

# %%
# Calculando los cuartiles y IQR
Q1 = df_numeric.quantile(0.25)
Q3 = df_numeric.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

sin_atipicos = pd.Series([True] * len(data))

for col in df_numeric.columns:
    valores_if = ((data[col] >= lower_bound[col]) & (data[col] <= upper_bound[col]))
    sin_atipicos = sin_atipicos & valores_if

df_sin_atipicos = data[sin_atipicos]

# %%
df_sin_atipicos.shape
# Out:
# (7362, 24)

# %%
print(f"{len(df_sin_atipicos) / len(data) * 100:.2f}%")
# Out:
# 14.35%

# %% [markdown]
# * Se confirma que las características Sales, Profit y Shipping cost, presentan una gran cantidad de valores atípicos en sus extremos. La detección de valores atípicos se realizó mediante el método de rango intercuartil (IQR). El 85,65% de los datos son considerados valores atípicos. Debido a esto, se recomienda aplicar métodos más robustos para la detección de anomalias como Factor de Valor Atípico Local(LOF) o Agrupamiento espacial basado en densidad de aplicacioens con ruido DBSCAN. Si el objetivo es solo detectar los valores atípicos se sugiere LOF y si se quiere identificar clústeres junto con los valores atípicos DBSCAN.

# %% [markdown]
# ## Análisis de correlaciones y relaciones entre variables

# %% [markdown]
# ### Matriz de correlación entre las variables numéricas

# %%
correlacion = data.select_dtypes(["int64", "float64"]).corr()

# Gráfico de mapa de correlación
fig, ax = plt.subplots(figsize=(15, 13))

sns.heatmap(correlacion, cbar=False, annot=True, fmt=".2f", ax=ax)
ax.set_title("Feature correlation", fontsize=16)
plt.tight_layout()
plt.show()

# %%
correlacion = data.select_dtypes(["int64", "float64"]).corr('spearman')

# Gráfico de mapa de correlación
fig, ax = plt.subplots(figsize=(15, 13))

sns.heatmap(correlacion, cbar=False, annot=True, fmt=".2f", ax=ax)
ax.set_title("Feature correlation", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# * Las características 'Sales' y 'Shipping Cost' tienen una relación fuerte positiva, lo que índica multicolinealidad se puede considerar eliminar alguna de ellas o aplicar PCA.
# (La multicolinealidad se considerara cuando una o más características tengan un coeficiente >0.8 o < -0.8)
# * Las características 'Profit' y 'Sales' tienen una relación moderada positiva (0.48). Estas características aún pueden aportar buena información de manera individual.
# * Las características 'Shipping Cost' y 'Profit' tienen una relación debíl positiva (0.35). Estas características aún pueden aportar buena información de manera individual.
# * Las características con un coeficiente inferior a 0.3 no es necesario intervenir, ya que no generan redundancia.
# * Las características con relaciones negativas no superan un coeficiente de 0.35, presentando una relación debíl o muy debíl, lo cuál no generan redundancia.

# %% [markdown]
# ### Comparar variables numéricas mediante gráficos de dispersión.

# %%
data.select_dtypes(["int64", "float"]).columns
# Out:
# Index(['Row ID', 'Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost'],
#       dtype='object')

# %%
rows, cols = 2, 2

fig, ax = plt.subplots(rows, cols, figsize=(15, 15))
ax = ax.flatten()

sns.scatterplot(data=data, x='Sales', y='Profit', hue='Segment', ax=ax[0])
ax[0].set_title("Sales vs Profit")

sns.scatterplot(data=data, x='Shipping Cost', y='Sales', hue='Segment', ax=ax[1])
ax[1].set_title("Shipping Cost vs Sales")

sns.scatterplot(data=data, x='Profit', y='Discount', hue='Segment', ax=ax[2])
ax[2].set_title("Profit vs Discount")

for j in range(3, len(ax)):
    ax[j].set_visible(False)
    
plt.show()

# %% [markdown]
# * Shipping cost y Sales presentan una relación monótoma creciente muy fuerte, semejante a una relación logaritmica. Se recomienda transformar los datos aplicando logaritmo.

# %% [markdown]
# ### Evaluación de relaciones entre variables categoricas y numéricas.

# %%
sns.boxplot(x='Segment', y='Sales', data=data)
plt.show()

# %%
sns.boxplot(x='Segment', y='Profit', data=data)
plt.show()

# %%
plt.figure(figsize=(20, 15))
sns.boxplot(x='Sub-Category', y='Sales', data=data)
plt.show()

# %% [markdown]
# * Las sub-categorias con un mayor valor Q2(media), representan mayores ventas para la empresa. Las sub-categorias Tables, Copiers, Bookcases son las más destacadas.
# * Las sub-categorias con un rango más amplio, las ventas tienen una mayor variabilidad. Tables, Appliances, BookCases, Machines, Phones, Copiers son las más destacadas.
# * Todas las sub-categorias cuentan con una gran cantidad de valores atípicos.
